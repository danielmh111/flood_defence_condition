# %%
import polars as pl
from project_paths import paths

df = pl.read_csv(paths.camels_data / 'camels_gb_v2_landcover_attributes.csv')

# %%
df.schema

# %%
df.head()

# %%
df.describe()

# %%
df.null_count()

# %%
(df.null_count() / len(df) * 100).transpose()
